# %% [markdown]
# - 행정구역 정보 분석 및 시각화

# %%
# !pip3 install openpyxl
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.2.3

# %%
data = pd.read_csv('data/data_draw_korea.csv')
print(type(data))
# 행과열 확인
print(data.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (229, 8)

# %%
#위에 데이터 두개만
data.head(2)
# Out:
#    Unnamed: 0     인구수 shortName   x  y       면적 광역시도 행정구역
# 0           0  202520        강릉  11  4  1040.07  강원도  강릉시
# 1           1   25589    고성(강원)   9  0   664.19  강원도  고성군

# %%
#마지막 데이터 3개
data.tail(3)
# Out:
#      Unnamed: 0     인구수 shortName  x   y      면적  광역시도 행정구역
# 226         226   62809        진천  5  11  406.08  충청북도  진천군
# 227         227  790216        청주  6  12  932.51  충청북도  청주시
# 228         228  198077        충주  6  10  983.70  충청북도  충주시

# %%
# 랜덤하게 데이터 추출
data.sample()
# Out:
#      Unnamed: 0     인구수 shortName   x   y      면적   광역시도 행정구역
# 153         153  203232      울산울주  11  15  754.93  울산광역시  울주군

# %%
# 칼럼 이름들
print(f'컬럼명 : {data.columns}')
# 자동으로 부여되는 인덱스
print(f'인덱스 : {data.index}')
# Out:
# 컬럼명 : Index(['Unnamed: 0', '인구수', 'shortName', 'x', 'y', '면적', '광역시도', '행정구역'], dtype='object')
# 인덱스 : RangeIndex(start=0, stop=229, step=1)

# %%
print(type(data.values))
print(data.values[0,2])
# array 변환된 값
data.values
# Out:
# <class 'numpy.ndarray'>
# 강릉
# array([[0, 202520, '강릉', ..., 1040.07, '강원도', '강릉시'],
#        [1, 25589, '고성(강원)', ..., 664.19, '강원도', '고성군'],
#        [2, 86747, '동해', ..., 180.01, '강원도', '동해시'],
#        ...,
#        [226, 62809, '진천', ..., 406.08, '충청북도', '진천군'],
#        [227, 790216, '청주', ..., 932.51, '충청북도', '청주시'],
#        [228, 198077, '충주', ..., 983.7, '충청북도', '충주시']],
#       shape=(229, 8), dtype=object)

# %%
# 데이터의 구조 및 요약 정보 출력
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  229 non-null    int64
#  1   인구수         229 non-null    int64
#  2   shortName   229 non-null    object
#  3   x           229 non-null    int64
#  4   y           229 non-null    int64
#  5   면적          229 non-null    float64
#  6   광역시도        229 non-null    object
#  7   행정구역        229 non-null    object
# dtypes: float64(1), int64(4), object(3)
# memory usage: 14.4+ KB

# %%
# 모든 컬럼의 타입 확인
print(type(data.dtypes))
data.dtypes
# Out:
# <class 'pandas.core.series.Series'>
# Unnamed: 0      int64
# 인구수             int64
# shortName      object
# x               int64
# y               int64
# 면적            float64
# 광역시도           object
# 행정구역           object
# dtype: object

# %%
#면적 컬럼의 타입을 확인
data.dtypes['면적']
# Out:
# dtype('float64')

# %%
# 특정컬럼(인구수)의 타입 확인
print(type(data['인구수']))
data['인구수'].dtypes
# Out:
# <class 'pandas.core.series.Series'>
# dtype('int64')

# %%
import numpy as np
data.describe(include=[np.number]) # 와 동일한 결과
#data.describe()
# 데이터 개수, 평균, 표준편차, 최소값, 사분위수, 최대값
# Out:
#        Unnamed: 0           인구수           x           y           면적
# count  229.000000  2.290000e+02  229.000000  229.000000   229.000000
# mean   114.000000  2.110898e+05    6.117904   11.262009   435.419795
# std     66.250786  2.074378e+05    3.320469    6.040898   381.612549
# min      0.000000  8.392000e+03    0.000000    0.000000     2.800000
# 25%     57.000000  4.955900e+04    3.000000    6.000000    54.000000
# 50%    114.000000  1.401590e+05    6.000000   11.000000   436.400000
# 75%    171.000000  3.216180e+05    9.000000   16.000000   692.800000
# max    228.000000  1.125461e+06   13.000000   25.000000  1817.940000

# %%
# 문자열(object) 타입인 컬럼의 통계함수 출력
'''
shrtName
- count: 총 229개의 데이터가 있음.
- unique: 그 중 229개의 값이 모두 유일함 (중복된 값 없음).
- top: 가장 자주 등장한 값은 "강릉".
- freq: "강릉"은 1번만 등장함.
'''
data.describe(include=[object])
# Out:
#        shortName 광역시도 행정구역
# count        229  229  229
# unique       229   17  206
# top           강릉  경기도   동구
# freq           1   31    6

# %%
data['행정구역'] == '동구'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 224    False
# 225    False
# 226    False
# 227    False
# 228    False
# Name: 행정구역, Length: 229, dtype: bool

# %%
# 해당 조건식과 매칭되는 Row data 출력
# 행정구역 열에서 , '동구' 인것만 필터링
data.loc[data['행정구역'] == '동구']
# Out:
#      Unnamed: 0     인구수 shortName   x   y      면적   광역시도 행정구역
# 92           92   97571      광주동구   3  20   48.86  광주광역시   동구
# 98           98  330830      대구동구  11  13  182.35  대구광역시   동구
# 104         104  236524      대전동구   5  13  136.80  대전광역시   동구
# 112         112   85952      부산동구  10  17    9.77  부산광역시   동구
# 151         151  164738      울산동구  12  14   35.77  울산광역시   동구
# 159         159   68950      인천동구   1   5    7.05  인천광역시   동구

# %%
'''
필터링 된 인후
.reset_index(drop=True) => 기존 인덱스 01234 로 재설정
'''
data.loc[data['광역시도'] == '경기도'].reset_index(drop=True)
# Out:
#     Unnamed: 0      인구수 shortName  x  y       면적 광역시도  행정구역
# 0           18    53497        가평  9  3  843.040  경기도   가평군
# 1           19   955384        고양  4  2  267.330  경기도   고양시
# 2           20    63227        과천  7  7   35.813  경기도   과천시
# 3           21   327111        광명  3  3   38.500  경기도   광명시
# 4           22   290210        광주  8  7  431.840  경기도   광주시
# 5           23   175676        구리  9  4   33.300  경기도   구리시
# 6           24   273302        군포  5  8   36.350  경기도   군포시
# 7           25   326523        김포  2  3  276.640  경기도   김포시
# 8           26   610300       남양주  8  3  458.440  경기도  남양주시
# 9           27    90398       동두천  7  2   95.680  경기도  동두천시
# 10          28   805473        부천  2  4   53.440  경기도   부천시
# 11          29   911628        성남  7  8  141.820  경기도   성남시
# 12          30  1125461        수원  6  9  121.090  경기도   수원시
# 13          31   381412        시흥  3  5  134.400  경기도   시흥시
# 14          32   668089        안산  3  6  144.780  경기도   안산시
# ...

# %%
# 모든 컬럼의 통계함수 출력
data.describe(include='all')
# Out:
#         Unnamed: 0           인구수 shortName           x           y  \
# count   229.000000  2.290000e+02       229  229.000000  229.000000
# unique         NaN           NaN       229         NaN         NaN
# top            NaN           NaN        강릉         NaN         NaN
# freq           NaN           NaN         1         NaN         NaN
# mean    114.000000  2.110898e+05       NaN    6.117904   11.262009
# std      66.250786  2.074378e+05       NaN    3.320469    6.040898
# min       0.000000  8.392000e+03       NaN    0.000000    0.000000
# 25%      57.000000  4.955900e+04       NaN    3.000000    6.000000
# 50%     114.000000  1.401590e+05       NaN    6.000000   11.000000
# 75%     171.000000  3.216180e+05       NaN    9.000000   16.000000
# max     228.000000  1.125461e+06       NaN   13.000000   25.000000
#
#                  면적 광역시도 행정구역
# count    229.000000  229  229
# unique          NaN   17  206
# top             NaN  경기도   동구
# freq            NaN   31    6
# ...

# %%
# 인구수 1개의 컬럼 선택
print(type(data['인구수']))
data['인구수']
# Out:
# <class 'pandas.core.series.Series'>
# 0      202520
# 1       25589
# 2       86747
# 3       63986
# 4       76733
#         ...
# 224    127462
# 225     34480
# 226     62809
# 227    790216
# 228    198077
# Name: 인구수, Length: 229, dtype: int64

# %%
data[['행정구역','인구수','면적']]
# Out:
#     행정구역     인구수       면적
# 0    강릉시  202520  1040.07
# 1    고성군   25589   664.19
# 2    동해시   86747   180.01
# 3    삼척시   63986  1185.80
# 4    속초시   76733   105.25
# ..   ...     ...      ...
# 224  제천시  127462   882.47
# 225  증평군   34480    81.84
# 226  진천군   62809   406.08
# 227  청주시  790216   932.51
# 228  충주시  198077   983.70
#
# [229 rows x 3 columns]

# %%
# 인구수 컬럼의 집계함수
print(f"인구수 최대값 {data['인구수'].max():,}")
print(f"인구수 최소값 {data['인구수'].min():,}")
print(f"인구수 평균 {round(data['인구수'].mean()):,}")
print(f"인구수 표준편차 {round(data['인구수'].std()):,}")
print(f"인구수 중간값 {data['인구수'].median():,}")
# 특정 분위수 계산
data['인구수'].quantile([0.25, 0.75])
# Out:
# 인구수 최대값 1,125,461
# 인구수 최소값 8,392
# 인구수 평균 211,090
# 인구수 표준편차 207,438
# 인구수 중간값 140,159.0
# 0.25     49559.0
# 0.75    321618.0
# Name: 인구수, dtype: float64

# %%
# 인구수가 가장 많은 행정구역?
max_prop = data['인구수'].max()
#data['인구수'] == max_prop
data.loc[data['인구수'] == max_prop]
# Out:
#     Unnamed: 0      인구수 shortName  x  y      면적 광역시도 행정구역
# 30          30  1125461        수원  6  9  121.09  경기도  수원시

# %%
# 면적이 넓은 행정구역?
max_area = data['면적'].max()
data.loc[data['면적'] == max_area]
# Out:
#     Unnamed: 0    인구수 shortName   x  y       면적 광역시도 행정구역
# 15          15  62957        홍천  10  4  1817.94  강원도  홍천군

# %%
# 인구수가 가장 적은 행정구역?
min_prop = data['인구수'].min()
data.loc[data['인구수'] == min_prop]
# Out:
#     Unnamed: 0   인구수 shortName   x  y     면적  광역시도 행정구역
# 83          83  8392        울릉  13  6  72.82  경상북도  울릉군

# %%
# unique한 광역시도명
print(len(data['광역시도'].unique()))
data['광역시도'].unique()
# Out:
# 17
# array(['강원도', '경기도', '경상남도', '경상북도', '광주광역시', '대구광역시', '대전광역시', '부산광역시',
#        '서울특별시', '세종특별자치시', '울산광역시', '인천광역시', '전라남도', '전라북도', '제주특별자치도',
#        '충청남도', '충청북도'], dtype=object)

# %%
# 광역시도별 Row Counting
data['광역시도'].value_counts()
# Out:
# 광역시도
# 경기도        31
# 서울특별시      25
# 경상북도       23
# 전라남도       22
# 강원도        18
# 경상남도       18
# 부산광역시      16
# 충청남도       15
# 전라북도       14
# 충청북도       11
# 인천광역시      10
# 대구광역시       8
# 대전광역시       5
# 광주광역시       5
# 울산광역시       5
# 제주특별자치도     2
# 세종특별자치시     1
# Name: count, dtype: int64

# %%
# 광역시도가 경기도인 것들의 행정구역.인구수.면적 조회
data.loc[data['광역시도'] == '경기도',['행정구역','인구수','면적']]
# Out:
#     행정구역      인구수       면적
# 18   가평군    53497  843.040
# 19   고양시   955384  267.330
# 20   과천시    63227   35.813
# 21   광명시   327111   38.500
# 22   광주시   290210  431.840
# 23   구리시   175676   33.300
# 24   군포시   273302   36.350
# 25   김포시   326523  276.640
# 26  남양주시   610300  458.440
# 27  동두천시    90398   95.680
# 28   부천시   805473   53.440
# 29   성남시   911628  141.820
# 30   수원시  1125461  121.090
# 31   시흥시   381412  134.400
# 32   안산시   668089  144.780
# 33   안성시   173061  554.200
# 34   안양시   566558   58.520
# 35   양주시   191266  310.310
# 36   양평군    95614  877.080
# 37   여주시   100669  608.640
# 38   연천군    41076  695.230
# 39   오산시   200793   42.740
# 40   용인시   915005  591.500
# 41   의왕시   149080   54.000
# 42  의정부시   408220   81.590
# 43   이천시   190537  461.020
# 44   파주시   385528  672.560
# 45   평택시   423763  452.310
# 46   포천시   140159  826.380
# 47   하남시   150061   93.100
# 48   화성시   555129  688.100

# %%
# 광역시도가 경기도인것들, '인구수'부터 '행정구역'까지 모든 열을 선택
data.loc[data['광역시도'] == '경기도','인구수':'행정구역'].sort_values(by='면적',ascending=False)
# Out:
#         인구수 shortName  x  y       면적 광역시도  행정구역
# 36    95614        양평  9  6  877.080  경기도   양평군
# 18    53497        가평  9  3  843.040  경기도   가평군
# 46   140159        포천  8  1  826.380  경기도   포천시
# 38    41076        연천  7  1  695.230  경기도   연천군
# 48   555129        화성  3  7  688.100  경기도   화성시
# 44   385528        파주  3  2  672.560  경기도   파주시
# 37   100669        여주  9  7  608.640  경기도   여주시
# 40   915005        용인  7  9  591.500  경기도   용인시
# 33   173061        안성  4  8  554.200  경기도   안성시
# 43   190537        이천  8  8  461.020  경기도   이천시
# 26   610300       남양주  8  3  458.440  경기도  남양주시
# 45   423763        평택  5  9  452.310  경기도   평택시
# 22   290210        광주  8  7  431.840  경기도   광주시
# 35   191266        양주  8  2  310.310  경기도   양주시
# 25   326523        김포  2  3  276.640  경기도   김포시
# 19   955384        고양  4  2  267.330  경기도   고양시
# 32   668089        안산  3  6  144.780  경기도   안산시
# 29   911628        성남  7  8  141.820  경기도   성남시
# 31   381412        시흥  3  5  134.400  경기도   시흥시
# ...

# %%
#경기도에 속한 행정구역명, 인구수, 면적 선택하기
#data.loc[row , col]

# 경기도 인구수 높은순으로 정렬, 인덱스 재정렬
gy_df=data.loc[data['광역시도'] == '경기도',['행정구역','인구수','면적']].sort_values(by='인구수',ascending=False).reset_index(drop=True)

'''
새로운 컬럼을 생성
- 인구수2는 숫자 천 단위
- 면적2는 소수점 2까지
'''
gy_df['인구수2']=gy_df['인구수'].map('{:,}'.format)
gy_df['면적2']=gy_df['면적'].map('{:.2f}'.format)
gy_df
# Out:
#     행정구역      인구수       면적       인구수2     면적2
# 0    수원시  1125461  121.090  1,125,461  121.09
# 1    고양시   955384  267.330    955,384  267.33
# 2    용인시   915005  591.500    915,005  591.50
# 3    성남시   911628  141.820    911,628  141.82
# 4    부천시   805473   53.440    805,473   53.44
# 5    안산시   668089  144.780    668,089  144.78
# 6   남양주시   610300  458.440    610,300  458.44
# 7    안양시   566558   58.520    566,558   58.52
# 8    화성시   555129  688.100    555,129  688.10
# 9    평택시   423763  452.310    423,763  452.31
# 10  의정부시   408220   81.590    408,220   81.59
# 11   파주시   385528  672.560    385,528  672.56
# 12   시흥시   381412  134.400    381,412  134.40
# 13   광명시   327111   38.500    327,111   38.50
# 14   김포시   326523  276.640    326,523  276.64
# 15   광주시   290210  431.840    290,210  431.84
# 16   군포시   273302   36.350    273,302   36.35
# 17   오산시   200793   42.740    200,793   42.74
# 18   양주시   191266  310.310    191,266  310.31
# ...

# %%
# 조건과 매핑되는 새로운 DataFrame 생성
# 면적이 1000이상인것들을 area_1000에 새로운 데이터프레임 생성
area_1000 = data.loc[data['면적'] > 1000].copy()

#면적2 컬럼을 생성
#df.loc[df['A'] > 2, 'B'] = new_val
# 데이터프레임에서 모든 행(:)에 대해 새로운 열인 '면적2'를 추가
area_1000.loc[:,'면적2']=area_1000['면적'].map('{:,.2f}'.format)
area_1000.sort_values(by="면적",ascending=False)
# Out:
#     Unnamed: 0     인구수 shortName   x   y       면적  광역시도 행정구역       면적2
# 15          15   62957        홍천  10   4  1817.94   강원도  홍천군  1,817.94
# 9            9   29260        인제   9   2  1646.08   강원도  인제군  1,646.08
# 77          77  157317        안동  10  10  1519.00  경상북도  안동시  1,519.00
# 14          14   38439        평창  10   6  1463.65   강원도  평창군  1,463.65
# 68          68  242618        경주  12  12  1323.85  경상북도  경주시  1,323.85
# 75          75   93305        상주   8   9  1254.82  경상북도  상주시  1,254.82
# 10          10   34242        정선  11   6  1220.67   강원도  정선군  1,220.67
# 74          74   30287        봉화  11   9  1201.00  경상북도  봉화군  1,201.00
# 3            3   63986        삼척  11   8  1185.80   강원도  삼척시  1,185.80
# 85          85   48776        의성  10  11  1175.89  경상북도  의성군  1,175.89
# 7            7   34966        영월  10   8  1127.36   강원도  영월군  1,127.36
# 89          89  488395        포항  12  11  1127.00  경상북도  포항시  1,127.00
# ...

# %%
#경기도 인구수의 평균과 표준편차
print(f"경기도 인구수 평균 = {gy_df['인구수'].mean()}")
print(f"경기도 인구수 편차 = {gy_df['인구수'].std()}")
#경기도 인구수 평균 = 378845.48387096776
# Out:
# 경기도 인구수 평균 = 378845.48387096776
# 경기도 인구수 편차 = 304548.3951420388

# %%
#광역시도명을 인자로 받아서 해당 광역시에 속한 행정구역들의 인구수의 평균과 편차 구하기
def pop_mean_std(sido_name):
    sido_df = data.loc[data['광역시도'] == sido_name,'인구수':'행정구역']
    print(f"{sido_name} 인구수 평균 = {sido_df['인구수'].mean()}")
    print(f"{sido_name} 인구수 편차 = {sido_df['인구수'].std()}")

# %%
pop_mean_std('서울특별시')
# Out:
# 서울특별시 인구수 평균 = 375792.28
# 서울특별시 인구수 편차 = 125231.24797500289

# %%
for sido_name in data['광역시도'].unique():
    pop_mean_std(sido_name)
# Out:
# 강원도 인구수 평균 = 79413.22222222222
# 강원도 인구수 편차 = 87316.38323837094
# 경기도 인구수 평균 = 378845.48387096776
# 경기도 인구수 편차 = 304548.3951420388
# 경상남도 인구수 평균 = 174693.72222222222
# 경상남도 인구수 편차 = 245796.4650767224
# 경상북도 인구수 평균 = 109085.39130434782
# 경상북도 인구수 편차 = 124954.74088490059
# 광주광역시 인구수 평균 = 287641.8
# 광주광역시 인구수 편차 = 137076.68320578814
# 대구광역시 인구수 평균 = 297306.25
# 대구광역시 인구수 편차 = 174375.39437968715
# 대전광역시 인구수 평균 = 293535.4
# 대전광역시 인구수 편차 = 111853.57188217103
# 부산광역시 인구수 평균 = 207724.4375
# 부산광역시 인구수 편차 = 106246.04138380481
# 서울특별시 인구수 평균 = 375792.28
# 서울특별시 인구수 편차 = 125231.24797500289
# 세종특별자치시 인구수 평균 = 191233.0
# 세종특별자치시 인구수 편차 = nan
# 울산광역시 인구수 평균 = 221117.0
# 울산광역시 인구수 편차 = 64163.28658196991
# 인천광역시 인구수 평균 = 276657.5
# 인천광역시 인구수 편차 = 199353.5964908417
# 전라남도 인구수 평균 = 77298.31818181818
# 전라남도 인구수 편차 = 74413.25322969876
# 전라북도 인구수 평균 = 124217.71428571429
# 전라북도 인구수 편차 = 168327.13482128442
# 제주특별자치도 인구수 평균 = 287936.5
# 제주특별자치도 인구수 편차 = 201620.89205362622
# 충청남도 인구수 평균 = 129741.93333333333
# ...

# %%
#loc[] 사용
#인덱스가 20 부터 25까지
data.loc[20:25]
# Out:
#     Unnamed: 0     인구수 shortName  x  y       면적 광역시도 행정구역
# 20          20   63227        과천  7  7   35.813  경기도  과천시
# 21          21  327111        광명  3  3   38.500  경기도  광명시
# 22          22  290210        광주  8  7  431.840  경기도  광주시
# 23          23  175676        구리  9  4   33.300  경기도  구리시
# 24          24  273302        군포  5  8   36.350  경기도  군포시
# 25          25  326523        김포  2  3  276.640  경기도  김포시

# %%
#iloc[] 사용
#인덱스가 20 부터 24까지
data.iloc[20:25]
# Out:
#     Unnamed: 0     인구수 shortName  x  y       면적 광역시도 행정구역
# 20          20   63227        과천  7  7   35.813  경기도  과천시
# 21          21  327111        광명  3  3   38.500  경기도  광명시
# 22          22  290210        광주  8  7  431.840  경기도  광주시
# 23          23  175676        구리  9  4   33.300  경기도  구리시
# 24          24  273302        군포  5  8   36.350  경기도  군포시

# %%
#iloc[row index, column index] 사용
#인덱스가 20 부터 24까지 컬럼이 인구수부터 행정구역 까지
data.iloc[20:25,1:8]
# Out:
#        인구수 shortName  x  y       면적 광역시도 행정구역
# 20   63227        과천  7  7   35.813  경기도  과천시
# 21  327111        광명  3  3   38.500  경기도  광명시
# 22  290210        광주  8  7  431.840  경기도  광주시
# 23  175676        구리  9  4   33.300  경기도  구리시
# 24  273302        군포  5  8   36.350  경기도  군포시

# %%
#loc[] 사용
#index가 40,55,60 이고, column이 인구수,광역시도,행정구역
data.loc[[40,55,60],['인구수','광역시도','행정구역']]
# Out:
#        인구수  광역시도 행정구역
# 40  915005   경기도  용인시
# 55  106388  경상남도  사천시
# 60   56734  경상남도  창녕군

# %%
#인덱스가 0인 행 하나만 선택
print(type(data.loc[0]))
data.loc[0]
# Out:
# <class 'pandas.core.series.Series'>
# Unnamed: 0          0
# 인구수            202520
# shortName          강릉
# x                  11
# y                   4
# 면적            1040.07
# 광역시도              강원도
# 행정구역              강릉시
# Name: 0, dtype: object

# %%
#열 하나만 선택
print(type(data['면적']))
# head() -> 상위 5개 출력
# 시리즈의 상위 n개 행을 출력 head(n)
data['면적'].head()
# Out:
# <class 'pandas.core.series.Series'>
# 0    1040.07
# 1     664.19
# 2     180.01
# 3    1185.80
# 4     105.25
# Name: 면적, dtype: float64

# %%
# 데이터 칼럼
data.columns
# Out:
# Index(['Unnamed: 0', '인구수', 'shortName', 'x', 'y', '면적', '광역시도', '행정구역'], dtype='object')

# %%
# 'Unnamed: 0' 컬럼명을 'seq' 로 변경한다. 원본 객체는 변경되지 않고 변경된 결과만 출력함
# inplace=True => 원본데이터 변경, false => 새로운 프레임 반환
data.rename(columns={'Unnamed: 0':'seq'}, inplace=False)
# Out:
#      seq     인구수 shortName   x   y       면적  광역시도 행정구역
# 0      0  202520        강릉  11   4  1040.07   강원도  강릉시
# 1      1   25589    고성(강원)   9   0   664.19   강원도  고성군
# 2      2   86747        동해  11   5   180.01   강원도  동해시
# 3      3   63986        삼척  11   8  1185.80   강원도  삼척시
# 4      4   76733        속초   9   1   105.25   강원도  속초시
# ..   ...     ...       ...  ..  ..      ...   ...  ...
# 224  224  127462        제천   8  10   882.47  충청북도  제천시
# 225  225   34480        증평   6  11    81.84  충청북도  증평군
# 226  226   62809        진천   5  11   406.08  충청북도  진천군
# 227  227  790216        청주   6  12   932.51  충청북도  청주시
# 228  228  198077        충주   6  10   983.70  충청북도  충주시
#
# [229 rows x 8 columns]

# %%
#원본 객체가 변경되고 변경된 결과는 출력하지 않는다.
data.rename(columns={'Unnamed: 0':'seq'}, inplace=True)
print(data.columns)
# Out:
# Index(['seq', '인구수', 'shortName', 'x', 'y', '면적', '광역시도', '행정구역'], dtype='object')

# %%
# seq 컬럼을 인덱스로 변경한다 ( 원본 객체가 변경됨 )
data.set_index('seq', inplace=True)

# %%
data.head(2)
# Out:
#         인구수 shortName   x  y       면적 광역시도 행정구역
# seq
# 0    202520        강릉  11  4  1040.07  강원도  강릉시
# 1     25589    고성(강원)   9  0   664.19  강원도  고성군

# %%
# 인구수의 평균값 구하기
pop_mean_value=data['인구수'].mean()
print(pop_mean_value)
print(round(pop_mean_value))
print(f'{pop_mean_value:.2f}')
# Out:
# 211089.77729257641
# 211090
# 211089.78

# %%
# 인구수의 평균값보다 작은 Row를 선택하고, '광역시도','행정구역','인구수' 컬럼값을 가져오기
# 정렬할때 광역시도는 ascending으로 , 인구수는 descending
pop_mean_lt_df = data.loc[data['인구수'] < pop_mean_value,['광역시도','행정구역','인구수']] \
    .sort_values(by=['광역시도','인구수'],ascending=[True,False]) \
    .reset_index(drop=True)
pop_mean_lt_df.head(3)
# Out:
#   광역시도 행정구역     인구수
# 0  강원도  강릉시  202520
# 1  강원도  동해시   86747
# 2  강원도  속초시   76733

# %%
# DataFrame의 to_excel() 함수를 사용하여 excel 파일로 저장
pop_mean_lt_df.to_excel('data/평균인구수미만지역.xlsx', engine='openpyxl')

# %%
# 인구수를 광역시도별로 그룹화 한다.
# 그룹화된 데이터들의 합을 구한다.
# 내림차순
data['인구수'].groupby(data['광역시도']).sum().sort_values(ascending=False)
# Out:
# 광역시도
# 경기도        11744210
# 서울특별시       9394807
# 부산광역시       3323591
# 경상남도        3144487
# 인천광역시       2766575
# 경상북도        2508964
# 대구광역시       2378450
# 충청남도        1946129
# 전라북도        1739048
# 전라남도        1700563
# 충청북도        1484720
# 대전광역시       1467677
# 광주광역시       1438209
# 강원도         1429438
# 울산광역시       1105585
# 제주특별자치도      575873
# 세종특별자치시      191233
# Name: 인구수, dtype: int64

# %%
# 광역시도 데이터를 그룹화 한다음, 그룹별로 더한다.
# 숫자형 데이터만 합산
data.groupby('광역시도').sum(numeric_only=True)
# Out:
#               인구수    x    y         면적
# 광역시도
# 강원도       1429438  173   68  16874.810
# 경기도      11744210  182  162  10179.743
# 경상남도      3144487  123  313  10437.460
# 경상북도      2508964  229  240  19021.850
# 광주광역시     1438209   12   99    501.280
# 대구광역시     2378450   74  111    885.690
# 대전광역시     1467677   23   66    539.640
# 부산광역시     3323591  162  276    763.240
# 서울특별시     9394807  142  111    605.390
# 세종특별자치시    191233    4   11    465.230
# 울산광역시     1105585   58   71    980.220
# 인천광역시     2766575   13   61   1022.910
# 전라남도      1700563   44  438  12008.390
# 전라북도      1739048   46  219   7907.220
# 제주특별자치도    575873    8   49   1848.480
# 충청남도      1946129   39  160   8272.270
# 충청북도      1484720   69  124   7397.310

# %%
# data['인구수'].groupby(data['광역시도']).sum().sort_values(ascending=False)
# 광역시도를 그룹핑한다.
# 그룹화된 광역도시중 인구수 합친다.
data.groupby('광역시도')['인구수'].sum().sort_values(ascending=False)
# Out:
# 광역시도
# 경기도        11744210
# 서울특별시       9394807
# 부산광역시       3323591
# 경상남도        3144487
# 인천광역시       2766575
# 경상북도        2508964
# 대구광역시       2378450
# 충청남도        1946129
# 전라북도        1739048
# 전라남도        1700563
# 충청북도        1484720
# 대전광역시       1467677
# 광주광역시       1438209
# 강원도         1429438
# 울산광역시       1105585
# 제주특별자치도      575873
# 세종특별자치시      191233
# Name: 인구수, dtype: int64

# %%
# 광역시도별 행정구역별 인구수의 합계
group_df = data.groupby(['광역시도','행정구역'])['인구수'].sum()
group_df
# Out:
# 광역시도  행정구역
# 강원도   강릉시     202520
#       고성군      25589
#       동해시      86747
#       삼척시      63986
#       속초시      76733
#                ...
# 충청북도  제천시     127462
#       증평군      34480
#       진천군      62809
#       청주시     790216
#       충주시     198077
# Name: 인구수, Length: 229, dtype: int64

# %%
group_df.to_excel('data/광역시도별행정구역별인구수의합계.xlsx', sheet_name='인구수')

# %%
# 엑셀 수치 데이터에 콤마찍기
# !pip install xlsxwriter
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('data/광역시도별인구수의합계1.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
group_df.to_excel(writer, sheet_name='인구수합계')

# Get the xlsxwriter workbook and worksheet objects.
workbook  = writer.book
worksheet = writer.sheets['인구수합계']

# #,###는 숫자를 천 단위마다 쉼표로 구분
num_format = workbook.add_format({'num_format': '#,###'})

# C:C엑셀 시트의 C열 전체를 의미
# none : 열 너비를 자동으로 설정
# num_foramt : C열의 표시 형식을 천 단위 콤마(쉼표) 형식으로 설정
worksheet.set_column('C:C', None, num_format)

# Close the Pandas Excel writer and output the Excel file.
writer.close() #_save()

# %% [markdown]
# ### 상관계수 (Correlation Coefficient)
# - 인구수와 면적 데이터간에 관련성이 있는지 살펴보기 위해서 상관계수 구하기
# - 상관계수 값은 -1 ~ 1 사이의 값이며, 0에 가까울 수록 관련성이 낮고, 1에 가까울 수록 관련성이 높다.
# - 음수는 반비례 (면적이 넓은 반면 인구수는 적은 경우), 양수는 비례 (면적이 넓고, 인구수도 높은 경우)
# - corr() 함수

# %%
#전국의 면적과 인구수의 상관계수 구하기
'''
1에 가까울수록 → 두 변수는 강한 양의 상관 관계 → 면적이 커질수록 인구수도 증가
0에 가까울수록 → 두 변수 간에 관련성이 없음
-1에 가까울수록 → 두 변수는 강한 음의 상관 관계 → 면적이 커질수록 인구수가 감소
'''
data['면적'].corr(data['인구수'])
# Out:
# np.float64(-0.3460351605045768)

# %%
#서울의 면적과 인구수의 상관계수 구하기
seoul_df = data.loc[data['광역시도'] == '서울특별시']
seoul_df['면적'].corr(seoul_df['인구수'])
# Out:
# np.float64(0.6644268188909778)

# %%
#경기도의 면적과 인구수의 상관계수 구하기
gy_df = data.loc[data['광역시도'] == '경기도']
gy_df['면적'].corr(gy_df['인구수'])
# Out:
# np.float64(-0.21572485071590813)

# %% [markdown]
# ### Groupby 한 DataFrame에 집계함수를 여러개 설정하기
# - agg() 함수
# - agg(['max','mean','std'])

# %%
# fillna(0) NaN 을 0 으로 변경해 줌
# 광역시도 기준으로 그룹화 + 그룹화를 할때 max mean std min 표현해라
'''
max → 최대값
mean → 평균값
std → 표준 편차(Standard Deviation)
min → 최소값
'''
data.groupby('광역시도')['인구수'].agg(['max','mean','std','min']).fillna(0)
# Out:
#              max           mean            std     min
# 광역시도
# 강원도       313851   79413.222222   87316.383238   20809
# 경기도      1125461  378845.483871  304548.395142   41076
# 경상남도     1010040  174693.722222  245796.465077   25091
# 경상북도      488395  109085.391304  124954.740885    8392
# 광주광역시     439683  287641.800000  137076.683206   97571
# 대구광역시     584517  297306.250000  174375.394380   74950
# 대전광역시     475094  293535.400000  111853.571882  190815
# 부산광역시     397134  207724.437500  106246.041384   43105
# 서울특별시     615487  375792.280000  125231.247975  114967
# 세종특별자치시   191233  191233.000000       0.000000  191233
# 울산광역시     327270  221117.000000   64163.286582  164738
# 인천광역시     527153  276657.500000  199353.596491   17735
# 전라남도      263166   77298.318182   74413.253230   23189
# 전라북도      630708  124217.714286  168327.134821   20492
# 제주특별자치도   430504  287936.500000  201620.892054  145369
# 충청남도      584912  129741.933333  141125.108080   29671
# ...

# %%
# agg() 함수 사용 - 그룹핑한 데이터를 여러개의 집계함수를 사용해서 새로운 DataFrame 객체 생성하기
# 해당 데이터를 통해서, 표준편차가 가장 큰 광역도시를 구할 수 있다.
group_agg_df = data.groupby('광역시도')['인구수'].agg(['max','mean','std']) \
    .fillna(0).sort_values(by='std',ascending=False)
group_agg_df
# Out:
#              max           mean            std
# 광역시도
# 경기도      1125461  378845.483871  304548.395142
# 경상남도     1010040  174693.722222  245796.465077
# 충청북도      790216  134974.545455  223460.356657
# 제주특별자치도   430504  287936.500000  201620.892054
# 인천광역시     527153  276657.500000  199353.596491
# 대구광역시     584517  297306.250000  174375.394380
# 전라북도      630708  124217.714286  168327.134821
# 충청남도      584912  129741.933333  141125.108080
# 광주광역시     439683  287641.800000  137076.683206
# 서울특별시     615487  375792.280000  125231.247975
# 경상북도      488395  109085.391304  124954.740885
# 대전광역시     475094  293535.400000  111853.571882
# 부산광역시     397134  207724.437500  106246.041384
# 강원도       313851   79413.222222   87316.383238
# 전라남도      263166   77298.318182   74413.253230
# 울산광역시     327270  221117.000000   64163.286582
# 세종특별자치시   191233  191233.000000       0.000000

# %%
group_agg_df.style.format('{0:.2f}')
# Out:
# <style type="text/css">
# </style>
# <table id="T_3ae7d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ae7d_level0_col0" class="col_heading level0 col0" >max</th>
#       <th id="T_3ae7d_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_3ae7d_level0_col2" class="col_heading level0 col2" >std</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >광역시도</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ae7d_level0_row0" class="row_heading level0 row0" >경기도</th>
#       <td id="T_3ae7d_row0_col0" class="data row0 col0" >1125461.00</td>
#       <td id="T_3ae7d_row0_col1" class="data row0 col1" >378845.48</td>
#       <td id="T_3ae7d_row0_col2" class="data row0 col2" >304548.40</td>
#     </tr>
#     <tr>
# ...

# %%
# 컬럼의 값을 변경하기 map() 함수를 사용하여 포맷하기
group_agg_df['mean'] = group_agg_df['mean'].map('{:.2f}'.format)
group_agg_df['std'] = group_agg_df['std'].map('{:.2f}'.format)
group_agg_df
# Out:
#              max       mean        std
# 광역시도
# 경기도      1125461  378845.48  304548.40
# 경상남도     1010040  174693.72  245796.47
# 충청북도      790216  134974.55  223460.36
# 제주특별자치도   430504  287936.50  201620.89
# 인천광역시     527153  276657.50  199353.60
# 대구광역시     584517  297306.25  174375.39
# 전라북도      630708  124217.71  168327.13
# 충청남도      584912  129741.93  141125.11
# 광주광역시     439683  287641.80  137076.68
# 서울특별시     615487  375792.28  125231.25
# 경상북도      488395  109085.39  124954.74
# 대전광역시     475094  293535.40  111853.57
# 부산광역시     397134  207724.44  106246.04
# 강원도       313851   79413.22   87316.38
# 전라남도      263166   77298.32   74413.25
# 울산광역시     327270  221117.00   64163.29
# 세종특별자치시   191233  191233.00       0.00

# %% [markdown]
# ### 시각화
# - %matplotlib inline 설정 (jupyter 에서는 show() 함수를 호출하지 않아도 plot이 출력된다)
# - 한글폰트 설정이 필요함
# - Plot에 대한 설정은 matplotlib의 함수를 사용하고, Plot을 그려주는 기능은 seaborn()의 함수를 사용합니다.

# %%
# Jupyter Notebook에서 Matplotlib 라이브러리의 그래프를 노트북 셀 안에 출력하도록 설정하는 명령어
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
import seaborn as sns # 데이터 시각화 라이브러리, matplotlib 기반

print('matplotlib ', matplotlib.__version__)
print('seaborn ', sns.__version__)
# Out:
# matplotlib  3.10.0
# seaborn  0.13.2

# %%
# for font in fm.fontManager.ttflist:
#     print((font.name, font.fname))
# 폰트이름과 폰트파일 정보 출력 list comprehension
for font in fm.findSystemFonts(fontpaths=None, fontext='ttf'):
    print(font)
[ (font.name, font.fname) for font in fm.fontManager.ttflist if 'Mal' in font.name ]
# Out:
# /System/Library/Fonts/Supplemental/Luminari.ttf
# /System/Library/Fonts/Supplemental/NotoSansCham-Regular.ttf
# /System/Library/Fonts/Supplemental/NotoSansAvestan-Regular.ttf
# /System/Library/Fonts/Supplemental/NotoSansOldSouthArabian-Regular.ttf
# /System/Library/Fonts/Supplemental/NISC18030.ttf
# /System/Library/Fonts/Supplemental/NotoSansSharada-Regular.ttf
# /System/Library/Fonts/Supplemental/NotoSansBrahmi-Regular.ttf
# /System/Library/Fonts/Supplemental/NotoSansMiao-Regular.ttf
# /System/Library/AssetsV2/com_apple_MobileAsset_Font7/28f00a24ba19995bab7249993e6e35d11011074a.asset/AssetData/Kai.ttf
# /System/Library/Fonts/Supplemental/Mshtakan.ttc
# /System/Library/Fonts/Helvetica.ttc
# /System/Library/Fonts/Supplemental/STIXSizFiveSymReg.otf
# /System/Library/AssetsV2/com_apple_MobileAsset_Font7/7eb2afb6cbdb982371bb615d532a887629d99bf4.asset/AssetData/BMYeongSung-Regular.otf
# /System/Library/Fonts/Supplemental/PlantagenetCherokee.ttf
# ...

# %%
# font name을 알고 있다면 생략가능
#한글폰트 path 설정
font_path = '/System/Library/Fonts/Supplemental/AppleGothic.ttf'
#font의 파일정보로 font name 을 알아내기
font_prop = fm.FontProperties(fname=font_path).get_name()
plt.rc('font', family=font_prop)
print(font_prop)
# Out:
# AppleGothic

# %% [markdown]
# ### Figure, Axes, Plot
# - Axes는 Plot이 실제 그려지는 공간
# - Figure는 Axes 보다 더 상위의 공간 : Figure을 여러개의 Axes로 분할해서 Plot를 그릴 수 있다
# - 비교) Axis는 X 축, Y축
# - seaborn의 barplot() 함수(막대그래프) 사용
# - Figure > Axues > Plot

# %%
seoul_df.head(3)
# Out:
#         인구수 shortName  x  y    면적   광역시도 행정구역
# seq
# 124  526157      서울강남  6  7  39.5  서울특별시  강남구
# 125  432028      서울강동  8  5  24.6  서울특별시  강동구
# 126  310292      서울강북  5  2  23.6  서울특별시  강북구

# %%
# plt.subplots() -> 두 개의 subplot(2행 1열)을 생성
figure,(axes1, axes2) = plt.subplots(nrows=2, ncols=1)
# figure.set_size_inches(18, 12) -> 전체 figure의 크기를 (18인치 x 12인치)로 설정
figure.set_size_inches(18,12)
print(figure)
print(axes1)
print(axes2)

# seabon -> sns 데이터 시각화 라이브러리, matplotlib 기반
'''
- sns.barplot() -> seaborn 바 차트를 생성
- x='행정구역', y='인구수' -> 행정구역별 인구수를 x축과 y축에 매핑
- data=seoul_df.sort_values(by='인구수', ascending=False) -> 인구수가 높은 순서대로 정렬
- ax=axes1 -> 첫 번째 subplot에 그린다.
- hue='행정구역' -> 색깔을 행정구역별로 다르게 표시
'''
sns.barplot(x='행정구역',y='인구수',data=seoul_df.sort_values(by='인구수',ascending=False),ax=axes1, hue='행정구역')
#sns.barplot(x='행정구역',y='인구수',data=seoul_df,ax=axes1, hue='행정구역', hue_order="인구수")
# 면적이 큰 순서대로 정렬
sns.barplot(x='행정구역',y='면적',data=seoul_df.sort_values(by='면적',ascending=False), ax=axes2, hue='행정구역')
plt.show()

# Figure : 큰 도화지
# Axes 개별 플롯이 들어갈 영역
# > 열(ncols)이 2개인 경우는 Figure(도화지) 안에 Axes(격자) 를 열 방향으로 나눈 것
# Plot : 실제로 그려지는 그래프
# Out:
# Figure(1800x1200)
# Axes(0.125,0.53;0.775x0.35)
# Axes(0.125,0.11;0.775x0.35)

# %%
# 광역시도 이름을 인자로 받아서 인구수와 면적을 그려주는 함수
def show_pop_area(sido_name):
    # 입력받은 광역시도에 해당하는 DataFrame 객체생성
    sido_df = data.loc[data['광역시도'] == sido_name]
    # Figure와 Axes 객체 생성
    figure, (axes1,axes2) = plt.subplots(nrows=2, ncols=1)
    # Figure size 확대
    figure.set_size_inches(18,12)

    pop_plot = sns.barplot(x='행정구역', y='인구수', data=sido_df.sort_values(by='인구수',ascending=False), ax=axes1,hue='행정구역')
    pop_plot.set_title(f'{sido_name} 행정구역별 인구수')
    area_plot = sns.barplot(x='행정구역', y='면적', data=sido_df.sort_values(by='면적',ascending=False), ax=axes2,hue='행정구역')
    area_plot.set_title(f'{sido_name} 행정구역별 면적')
    plt.show()

# %%
show_pop_area('경기도')

# %%
# 전국데이터의 광역시도의 인구수
# 행1, 열1 axes1 을 만든다.
figure, axes1 = plt.subplots(1,1)
figure.set_size_inches(18,12)
# 바그래프를 그린다.
sns.barplot(x='광역시도', y='인구수', data=data, ax=axes1, hue='광역시도')
plt.show()

# %%
figure, ax1 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18,12)
sns.barplot(data=seoul_df, x="행정구역", y="인구수", ax=ax1,hue='행정구역')
#y축의 label값에 ,(콤마) 출력하기
ax1.get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, loc: "{:,}".format(int(x))))
#ax1.set(ylabel='인구수')

# 행정구역 이름돌리기
for item in ax1.get_xticklabels():
    item.set_rotation(90)

# matplotlib에서 barplot 위에 값(label)을 표시
'''
- enumerate(seoul_df["인구수"].items())
 > i, 인덱스 (x축 위치)
 > v, 튜플 형태로 (index, value) 값 반환 → v[1]은 실제 값 (y축위치_막대의 값)
- color='m'
 > 텍스트 생삭
- va='bottom'
 > 텍스트 위치 조정 (막대 위에 표시)

'''
for i, v in enumerate(seoul_df["인구수"].items()):
    ax1.text(i ,v[1], "{:,}".format(v[1]), color='m', va ='bottom', rotation=45)
plt.tight_layout()
